# %% [markdown]
# <a href="https://colab.research.google.com/github/maitri-7/DaLab/blob/main/EXP4_LRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,f1_score
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv("https://raw.githubusercontent.com/TarekDib03/Analytics/master/Week2%20-%20Linear%20Regression/Data/climate_change.csv")

# %%
df.head()
# Out:
#    Year  Month    MEI     CO2      CH4      N2O   CFC-11   CFC-12        TSI  \
# 0  1983      5  2.556  345.96  1638.59  303.677  191.324  350.113  1366.1024
# 1  1983      6  2.167  345.52  1633.71  303.746  192.057  351.848  1366.1208
# 2  1983      7  1.741  344.15  1633.22  303.795  192.818  353.725  1366.2850
# 3  1983      8  1.130  342.25  1631.35  303.839  193.602  355.633  1366.4202
# 4  1983      9  0.428  340.17  1648.40  303.901  194.392  357.465  1366.2335
#
#    Aerosols   Temp
# 0    0.0863  0.109
# 1    0.0794  0.118
# 2    0.0731  0.137
# 3    0.0673  0.176
# 4    0.0619  0.149

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      308 non-null    int64
#  1   Month     308 non-null    int64
#  2   MEI       308 non-null    float64
#  3   CO2       308 non-null    float64
#  4   CH4       308 non-null    float64
#  5   N2O       308 non-null    float64
#  6   CFC-11    308 non-null    float64
#  7   CFC-12    308 non-null    float64
#  8   TSI       308 non-null    float64
#  9   Aerosols  308 non-null    float64
#  10  Temp      308 non-null    float64
# dtypes: float64(9), int64(2)
# memory usage: 26.6 KB

# %%
df = df.drop(['Month',],axis=1)

# %%
df.corr()
# Out:
#               Year       MEI       CO2       CH4       N2O    CFC-11  \
# Year      1.000000 -0.145345  0.985379  0.910563  0.994850  0.460965
# MEI      -0.145345  1.000000 -0.152911 -0.105555 -0.162375  0.088171
# CO2       0.985379 -0.152911  1.000000  0.872253  0.981135  0.401284
# CH4       0.910563 -0.105555  0.872253  1.000000  0.894409  0.713504
# N2O       0.994850 -0.162375  0.981135  0.894409  1.000000  0.412155
# CFC-11    0.460965  0.088171  0.401284  0.713504  0.412155  1.000000
# CFC-12    0.870067 -0.039836  0.823210  0.958237  0.839295  0.831381
# TSI       0.022353 -0.076826  0.017867  0.146335  0.039892  0.284629
# Aerosols -0.361884  0.352351 -0.369265 -0.290381 -0.353499 -0.032302
# Temp      0.755731  0.135292  0.748505  0.699697  0.743242  0.380111
#
#             CFC-12       TSI  Aerosols      Temp
# Year      0.870067  0.022353 -0.361884  0.755731
# MEI      -0.039836 -0.076826  0.352351  0.135292
# CO2       0.823210  0.017867 -0.369265  0.748505
# ...

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
# split the dataset
X_train = X[X['Year']<=2006]
X_test = X[X['Year']>2006]
y_train = y[:len(X_train)]
y_test = y[len(X_train):]
X_train = X_train = X_train.drop(["Year"],axis=1)
X_test = X_test.drop(["Year"],axis=1)

# %%
print(df.isnull().sum())
# Out:
# Year        0
# MEI         0
# CO2         0
# CH4         0
# N2O         0
# CFC-11      0
# CFC-12      0
# TSI         0
# Aerosols    0
# Temp        0
# dtype: int64

# %% [markdown]
# **Linear Regression**

# %%
from statsmodels.api import OLS
model = OLS(y_train,X_train).fit()
model.rsquared
#R2 score of training data is 90% using the OLS library
# Out:
# 0.9010942288014989

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   Temp   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.898
# Method:                 Least Squares   F-statistic:                              314.3
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):                   7.35e-134
# Time:                        06:25:51   Log-Likelihood:                          261.15
# No. Observations:                 284   AIC:                                     -506.3
# Df Residuals:                     276   BIC:                                     -477.1
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
linreg=LinearRegression()
linreg.fit(X_train,y_train)
y_pred=linreg.predict(X_test)

# %%
Accuracy=r2_score(y_test,y_pred)
print("R2 score of the testing data is %.2f" %Accuracy)
linreg.score(X_test, y_test)
# Out:
# R2 score of the testing data is 0.18
# 0.18377835333134962

# %% [markdown]
# **Exercise 2 and 3**
#
# ---

# %%
df.corr()
# Out:
#               Year       MEI       CO2       CH4       N2O    CFC-11  \
# Year      1.000000 -0.145345  0.985379  0.910563  0.994850  0.460965
# MEI      -0.145345  1.000000 -0.152911 -0.105555 -0.162375  0.088171
# CO2       0.985379 -0.152911  1.000000  0.872253  0.981135  0.401284
# CH4       0.910563 -0.105555  0.872253  1.000000  0.894409  0.713504
# N2O       0.994850 -0.162375  0.981135  0.894409  1.000000  0.412155
# CFC-11    0.460965  0.088171  0.401284  0.713504  0.412155  1.000000
# CFC-12    0.870067 -0.039836  0.823210  0.958237  0.839295  0.831381
# TSI       0.022353 -0.076826  0.017867  0.146335  0.039892  0.284629
# Aerosols -0.361884  0.352351 -0.369265 -0.290381 -0.353499 -0.032302
# Temp      0.755731  0.135292  0.748505  0.699697  0.743242  0.380111
#
#             CFC-12       TSI  Aerosols      Temp
# Year      0.870067  0.022353 -0.361884  0.755731
# MEI      -0.039836 -0.076826  0.352351  0.135292
# CO2       0.823210  0.017867 -0.369265  0.748505
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   Temp   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.898
# Method:                 Least Squares   F-statistic:                              314.3
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):                   7.35e-134
# Time:                        06:26:14   Log-Likelihood:                          261.15
# No. Observations:                 284   AIC:                                     -506.3
# Df Residuals:                     276   BIC:                                     -477.1
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# From the summary we can say that MEI, CO2, CFC.11, CFC.12, TSI, and Aerosols are all significant(Since their p value is less than 0.05).

# %%
df_train = df[df['Year'] <= 2006]
df_test  = df[df['Year'] > 2006]
X_train = df_train[["MEI","CO2","CFC-11","CFC-12","TSI","Aerosols"]]
X_test = df_test[["MEI","CO2","CFC-11","CFC-12","TSI","Aerosols"]]
Y_train  = df_train[["Temp"]]
Y_test  = df_test[["Temp"]]

# %%
linreg=LinearRegression()
linreg.fit(X_train,Y_train)

from statsmodels.api import OLS
model = OLS(Y_train,X_train).fit()
model.rsquared
# Out:
# 0.9003190370297778

# %% [markdown]
# Our model isn't affected much when we use these attributes MEI, CO2, CFC.11, CFC.12, TSI, and Aerosols
